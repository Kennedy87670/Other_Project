# %% [markdown]
# <a href="https://colab.research.google.com/github/Kennedy87670/Other_Project/blob/main/Paddy_Disease_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload() # Browse for the kaggle.json file that you downloaded

# %%
# Make directory named kaggle, copy kaggle.json file there, and change the permissions of the file.
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Listing out all competition datasets in kaggle
! kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         42           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes         69           False
# store-sales-time-series-forecasting            2030-06-30 23:59:00  Getting Started  Knowledge        582           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge         98           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       1127           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      13357           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       3954            True
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        239           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge        730           False
# spaceship-titanic                              2030-01-01 00:00:00  Getting Started  Knowledge       2251           False
# competitive-data-science-predict-future-sales  2022-12-31 23:59:00  Playground           Kudos      15461           False
# feedback-prize-english-language-learning       2022-11-29 23:59:00  Featured           $55,000        815           False
# open-problems-multimodal                       2022-11-15 23:59:00  Featured           $25,000        588           False
# AI4Code                                        2022-11-10 23:59:00  Featured          $150,000        917           False
# big-data-derby-2022                            2022-11-10 23:59:00  Analytics          $50,000          0           False
# rsna-2022-cervical-spine-fracture-detection    2022-10-27 23:59:00  Featured           $30,000        471           False
# dfl-bundesliga-data-shootout                   2022-10-13 23:59:00  Featured           $25,000        360           False
# google-universal-image-embedding               2022-10-10 23:59:00  Research           $50,000        925           False
# jpx-tokyo-stock-exchange-prediction            2022-10-07 23:59:00  Featured           $63,000       2033           False
# mayo-clinic-strip-ai                           2022-10-05 23:59:00  Research           $10,000        737           False

# %%
# !kaggle competitions download -c paddy-disease-classification
# Out:
# Downloading paddy-disease-classification.zip to /content
# 100% 1.01G/1.02G [00:18<00:00, 72.3MB/s]
# 100% 1.02G/1.02G [00:18<00:00, 58.2MB/s]

# %%
# Unzipping downloaded data
! unzip paddy-disease-classification.zip

# %%
# Get helper functions file
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Out:
# --2022-09-20 19:28:17--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0.001s
#
# 2022-09-20 19:28:18 (15.7 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
# Import series of helper functions for the notebook (we've created/used these in previous notebooks)
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir

# %%
import tensorflow as tf

# %%
# Setting up paths to directories
train_dir="train_images"
test_dir="test_images"

# %%
walk_through_dir('train_images')
# Out:
# There are 10 directories and 0 images in 'train_images'.
# There are 0 directories and 337 images in 'train_images/bacterial_panicle_blight'.
# There are 0 directories and 380 images in 'train_images/bacterial_leaf_streak'.
# There are 0 directories and 965 images in 'train_images/brown_spot'.
# There are 0 directories and 1594 images in 'train_images/hispa'.
# There are 0 directories and 479 images in 'train_images/bacterial_leaf_blight'.
# There are 0 directories and 1764 images in 'train_images/normal'.
# There are 0 directories and 620 images in 'train_images/downy_mildew'.
# There are 0 directories and 1738 images in 'train_images/blast'.
# There are 0 directories and 1442 images in 'train_images/dead_heart'.
# There are 0 directories and 1088 images in 'train_images/tungro'.

# %%
# Loading in training data into batches from directory and spliting it into training and validation set
IMG_SIZE=(224,224)
train_data=tf.keras.utils.image_dataset_from_directory(directory=train_dir,
                                                       label_mode="categorical",
                                                       image_size=IMG_SIZE,
                                                       seed=42,
                                                       validation_split=0.2,
                                                       subset="training")

valid_data=tf.keras.utils.image_dataset_from_directory(directory=train_dir,
                                                       label_mode="categorical",
                                                       image_size=IMG_SIZE,
                                                       seed=42,
                                                       validation_split=0.2,
                                                       subset="validation")
# Out:
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.
# Found 10407 files belonging to 10 classes.
# Using 2081 files for validation.

# %%
# Getting class_names
class_names=train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %% [markdown]
# ## Visualizing training images

# %%
# Creating a function to visualize random images from training data
# Importing matplotlib library
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

def view_random_images(target_dir):
  plt.figure(figsize=(10,10))
  for i in range(8):
    plt.subplot(4,4,i+1)
    target_class=random.choice(class_names)
    target_folder=target_dir+"/"+target_class
    random_image=random.sample(os.listdir(target_folder),1)
    print(random_image)
    target_image=target_dir+"/"+target_class+"/"+random_image[0]

    # Reading in and plotting image using matplotlib
    img=mpimg.imread(target_image)
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off");

# %%
# Visualizing random images from training data
view_random_images("train_images")
# Out:
# ['109123.jpg']
# ['105371.jpg']
# ['101940.jpg']
# ['110054.jpg']
# ['105758.jpg']
# ['102202.jpg']
# ['106539.jpg']
# ['105119.jpg']

# %% [markdown]
# ## setup for modelling

# %%
# Creating learning rate reduction callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",  
                                                 factor=0.2, # multiply the learning rate by 0.2 (reduce by 5x)
                                                 patience=2,
                                                 verbose=1, # print out when learning rate goes down 
                                                 min_lr=1e-7)

# Creating ModelCheckpoint callback
model_checkpoint=tf.keras.callbacks.ModelCheckpoint(filepath='model_checkpoint/',
                                                    save_weights_only=True,
                                                    save_freq="epoch")

# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", # watch the val loss metric
                                                  patience=3) # if val loss decreases for 3 epochs in a row, stop training

# %% [markdown]
# ## Setting mixed precision
# for float 64

# %%
# Importing mixed precision
from tensorflow.keras import mixed_precision

# Setting up mixed precision training in order to make training run faster and use less memory
mixed_precision.set_global_policy("mixed_float16")
mixed_precision.global_policy()
# Out:
# <Policy "mixed_float16">

# %%
from tensorflow.keras import layers

# create base model
input_shape = (224, 224, 3)
base_model =tf.keras.applications.EfficientNetB1(include_top=False)
base_model.trainable = False # freeze base model layers

# Create Functional model
inputs = layers.Input(shape=input_shape, name= "input_layer")
# Note: EfficientNetBX models have rescaling built-in but if your model didn't you could have a layer like below
# x = layers.Rescaling(1./255)(x)
x = base_model(inputs, training=False)  # set base_model to inference mode only
x=tf.keras.layers.GlobalAveragePooling2D(name="global_average_pool")(x)
x= tf.keras.layers.Dense(128,  activation='relu')(x)
x = tf.keras.layers.Dense(len(class_names))(x) # want one output neuron per class
outputs = layers.Activation("softmax", dtype=tf.float32, name="softmax_float32")(x) 
model = tf.keras.Model(inputs, outputs)

# %%
# Get a summary of model
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  efficientnetb1 (Functional)  (None, None, None, 1280)  6575239
#
#  global_average_pool (Global  (None, 1280)             0
#  AveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               163968
#
#  dense_5 (Dense)             (None, 10)                1290
#
#  softmax_float32 (Activation  (None, 10)               0
#  )
#
# =================================================================
# Total params: 6,740,497
# Trainable params: 165,258
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

initial_epoch =15
# fitting model
history = model.fit(train_data,
                    epochs= initial_epoch,
                    steps_per_epoch=len(train_data),
                    validation_data = valid_data,
                    validation_steps =len(valid_data),
                    callbacks=[create_tensorboard_callback("training_logs", "efficientb1 Paddy disease_all_data_fine_tuning"), # track the model training logs
                                                                   model_checkpoint, # save only the best model during training
                                                                   early_stopping, # stop model after X epochs of no improvements
                                                                   reduce_lr]) # reduce the learning rate after X epochs of no improvements
# Out:
# Saving TensorBoard log files to: training_logs/efficientb1 Paddy disease_all_data_fine_tuning/20220920-210120
# Epoch 1/15
# 261/261 [==============================] - 37s 111ms/step - loss: 1.2579 - accuracy: 0.5796 - val_loss: 0.9870 - val_accuracy: 0.6708 - lr: 0.0010
# Epoch 2/15
# 261/261 [==============================] - 27s 103ms/step - loss: 0.7984 - accuracy: 0.7442 - val_loss: 0.7693 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 3/15
# 261/261 [==============================] - 28s 104ms/step - loss: 0.6182 - accuracy: 0.8102 - val_loss: 0.6139 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 4/15
# 261/261 [==============================] - 27s 102ms/step - loss: 0.4940 - accuracy: 0.8487 - val_loss: 0.5533 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 5/15
# 261/261 [==============================] - 27s 103ms/step - loss: 0.4084 - accuracy: 0.8787 - val_loss: 0.4922 - val_accuracy: 0.8510 - lr: 0.0010
# Epoch 6/15
# 261/261 [==============================] - 27s 103ms/step - loss: 0.3404 - accuracy: 0.8996 - val_loss: 0.4397 - val_accuracy: 0.8616 - lr: 0.0010
# Epoch 7/15
# 261/261 [==============================] - 28s 103ms/step - loss: 0.2871 - accuracy: 0.9162 - val_loss: 0.4297 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 8/15
# 261/261 [==============================] - 28s 104ms/step - loss: 0.2443 - accuracy: 0.9295 - val_loss: 0.3933 - val_accuracy: 0.8794 - lr: 0.0010
# Epoch 9/15
# 261/261 [==============================] - 28s 105ms/step - loss: 0.2119 - accuracy: 0.9403 - val_loss: 0.3654 - val_accuracy: 0.8818 - lr: 0.0010
# Epoch 10/15
# 261/261 [==============================] - 28s 103ms/step - loss: 0.1764 - accuracy: 0.9502 - val_loss: 0.3955 - val_accuracy: 0.8784 - lr: 0.0010
# Epoch 11/15
# 261/261 [==============================] - 28s 105ms/step - loss: 0.1545 - accuracy: 0.9578 - val_loss: 0.3236 - val_accuracy: 0.8996 - lr: 0.0010
# Epoch 12/15
# 261/261 [==============================] - 27s 103ms/step - loss: 0.1340 - accuracy: 0.9641 - val_loss: 0.3241 - val_accuracy: 0.9029 - lr: 0.0010
# Epoch 13/15
# 260/261 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9702
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 261/261 [==============================] - 27s 103ms/step - loss: 0.1195 - accuracy: 0.9702 - val_loss: 0.3258 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 14/15
# 261/261 [==============================] - 28s 104ms/step - loss: 0.0777 - accuracy: 0.9850 - val_loss: 0.2881 - val_accuracy: 0.9149 - lr: 2.0000e-04
# Epoch 15/15
# 261/261 [==============================] - 27s 103ms/step - loss: 0.0722 - accuracy: 0.9868 - val_loss: 0.2905 - val_accuracy: 0.9154 - lr: 2.0000e-04

# %% [markdown]
# ## Check the performance of the feature extraction model on validation data

# %%
# Evaluating feature extraction model
result_feature_extraction=model.evaluate(valid_data)
result_feature_extraction
# Out:
# 66/66 [==============================] - 6s 77ms/step - loss: 0.2905 - accuracy: 0.9154
# [0.29047954082489014, 0.9154253005981445]

# %%
# PLot loss cures
plot_loss_curves(history)

# %%
# Are any of the layers in our model frozen?
for layer in model.layers:
    layer.trainable = True # set all layers to trainable
    print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy) # make sure loaded model is using mixed precision dtype_policy ("mixed_float16")
# Out:
# input_layer True float32 <Policy "float32">
# efficientnetb1 True float32 <Policy "mixed_float16">
# global_average_pool True float32 <Policy "mixed_float16">
# dense_4 True float32 <Policy "mixed_float16">
# dense_5 True float32 <Policy "mixed_float16">
# softmax_float32 True float32 <Policy "float32">

# %% [markdown]
# IMproving the performance of feature extraction model by fine-funing the last 10 layers

# %%
# Setting base_model to trainable
base_model.trainable=True

# Freezing all layers except the last 10 layers
for layer in base_model.layers[:-10]:
  layer.trainable=False

# %%
# Checking layers in base_model
for num,layer in enumerate(base_model.layers):
  print(num,layer.name,layer.trainable)
# Out:
# 0 input_3 False
# 1 rescaling_2 False
# 2 normalization_2 False
# 3 stem_conv_pad False
# 4 stem_conv False
# 5 stem_bn False
# 6 stem_activation False
# 7 block1a_dwconv False
# 8 block1a_bn False
# 9 block1a_activation False
# 10 block1a_se_squeeze False
# 11 block1a_se_reshape False
# 12 block1a_se_reduce False
# 13 block1a_se_expand False
# 14 block1a_se_excite False
# 15 block1a_project_conv False
# 16 block1a_project_bn False
# 17 block1b_dwconv False
# 18 block1b_bn False
# 19 block1b_activation False
# 20 block1b_se_squeeze False
# 21 block1b_se_reshape False
# 22 block1b_se_reduce False
# 23 block1b_se_expand False
# 24 block1b_se_excite False
# 25 block1b_project_conv False
# 26 block1b_project_bn False
# 27 block1b_drop False
# 28 block1b_add False
# 29 block2a_expand_conv False
# 30 block2a_expand_bn False
# 31 block2a_expand_activation False
# 32 block2a_dwconv_pad False
# 33 block2a_dwconv False
# 34 block2a_bn False
# 35 block2a_activation False
# 36 block2a_se_squeeze False
# 37 block2a_se_reshape False
# 38 block2a_se_reduce False
# 39 block2a_se_expand False
# 40 block2a_se_excite False
# 41 block2a_project_conv False
# 42 block2a_project_bn False
# 43 block2b_expand_conv False
# 44 block2b_expand_bn False
# 45 block2b_expand_activation False
# 46 block2b_dwconv False
# 47 block2b_bn False
# 48 block2b_activation False
# 49 block2b_se_squeeze False
# 50 block2b_se_reshape False
# 51 block2b_se_reduce False
# 52 block2b_se_expand False
# 53 block2b_se_excite False
# 54 block2b_project_conv False
# 55 block2b_project_bn False
# 56 block2b_drop False
# 57 block2b_add False
# 58 block2c_expand_conv False
# 59 block2c_expand_bn False
# 60 block2c_expand_activation False
# 61 block2c_dwconv False
# 62 block2c_bn False
# 63 block2c_activation False
# 64 block2c_se_squeeze False
# 65 block2c_se_reshape False
# 66 block2c_se_reduce False
# 67 block2c_se_expand False
# 68 block2c_se_excite False
# 69 block2c_project_conv False
# 70 block2c_project_bn False
# 71 block2c_drop False
# 72 block2c_add False
# 73 block3a_expand_conv False
# 74 block3a_expand_bn False
# 75 block3a_expand_activation False
# 76 block3a_dwconv_pad False
# 77 block3a_dwconv False
# 78 block3a_bn False
# 79 block3a_activation False
# 80 block3a_se_squeeze False
# 81 block3a_se_reshape False
# 82 block3a_se_reduce False
# 83 block3a_se_expand False
# 84 block3a_se_excite False
# 85 block3a_project_conv False
# 86 block3a_project_bn False
# 87 block3b_expand_conv False
# 88 block3b_expand_bn False
# 89 block3b_expand_activation False
# 90 block3b_dwconv False
# 91 block3b_bn False
# 92 block3b_activation False
# 93 block3b_se_squeeze False
# 94 block3b_se_reshape False
# 95 block3b_se_reduce False
# 96 block3b_se_expand False
# 97 block3b_se_excite False
# 98 block3b_project_conv False
# 99 block3b_project_bn False
# 100 block3b_drop False
# 101 block3b_add False
# 102 block3c_expand_conv False
# 103 block3c_expand_bn False
# 104 block3c_expand_activation False
# 105 block3c_dwconv False
# 106 block3c_bn False
# 107 block3c_activation False
# 108 block3c_se_squeeze False
# 109 block3c_se_reshape False
# 110 block3c_se_reduce False
# 111 block3c_se_expand False
# 112 block3c_se_excite False
# 113 block3c_project_conv False
# 114 block3c_project_bn False
# 115 block3c_drop False
# 116 block3c_add False
# 117 block4a_expand_conv False
# 118 block4a_expand_bn False
# 119 block4a_expand_activation False
# 120 block4a_dwconv_pad False
# 121 block4a_dwconv False
# 122 block4a_bn False
# 123 block4a_activation False
# 124 block4a_se_squeeze False
# 125 block4a_se_reshape False
# 126 block4a_se_reduce False
# 127 block4a_se_expand False
# 128 block4a_se_excite False
# 129 block4a_project_conv False
# 130 block4a_project_bn False
# 131 block4b_expand_conv False
# 132 block4b_expand_bn False
# 133 block4b_expand_activation False
# 134 block4b_dwconv False
# 135 block4b_bn False
# 136 block4b_activation False
# 137 block4b_se_squeeze False
# 138 block4b_se_reshape False
# 139 block4b_se_reduce False
# 140 block4b_se_expand False
# 141 block4b_se_excite False
# 142 block4b_project_conv False
# 143 block4b_project_bn False
# 144 block4b_drop False
# 145 block4b_add False
# 146 block4c_expand_conv False
# 147 block4c_expand_bn False
# 148 block4c_expand_activation False
# 149 block4c_dwconv False
# 150 block4c_bn False
# 151 block4c_activation False
# 152 block4c_se_squeeze False
# 153 block4c_se_reshape False
# 154 block4c_se_reduce False
# 155 block4c_se_expand False
# 156 block4c_se_excite False
# 157 block4c_project_conv False
# 158 block4c_project_bn False
# 159 block4c_drop False
# 160 block4c_add False
# 161 block4d_expand_conv False
# 162 block4d_expand_bn False
# 163 block4d_expand_activation False
# 164 block4d_dwconv False
# 165 block4d_bn False
# 166 block4d_activation False
# 167 block4d_se_squeeze False
# 168 block4d_se_reshape False
# 169 block4d_se_reduce False
# 170 block4d_se_expand False
# 171 block4d_se_excite False
# 172 block4d_project_conv False
# 173 block4d_project_bn False
# 174 block4d_drop False
# 175 block4d_add False
# 176 block5a_expand_conv False
# 177 block5a_expand_bn False
# 178 block5a_expand_activation False
# 179 block5a_dwconv False
# 180 block5a_bn False
# 181 block5a_activation False
# 182 block5a_se_squeeze False
# 183 block5a_se_reshape False
# 184 block5a_se_reduce False
# 185 block5a_se_expand False
# 186 block5a_se_excite False
# 187 block5a_project_conv False
# 188 block5a_project_bn False
# 189 block5b_expand_conv False
# 190 block5b_expand_bn False
# 191 block5b_expand_activation False
# 192 block5b_dwconv False
# 193 block5b_bn False
# 194 block5b_activation False
# 195 block5b_se_squeeze False
# 196 block5b_se_reshape False
# 197 block5b_se_reduce False
# 198 block5b_se_expand False
# 199 block5b_se_excite False
# 200 block5b_project_conv False
# 201 block5b_project_bn False
# 202 block5b_drop False
# 203 block5b_add False
# 204 block5c_expand_conv False
# 205 block5c_expand_bn False
# 206 block5c_expand_activation False
# 207 block5c_dwconv False
# 208 block5c_bn False
# 209 block5c_activation False
# 210 block5c_se_squeeze False
# 211 block5c_se_reshape False
# 212 block5c_se_reduce False
# 213 block5c_se_expand False
# 214 block5c_se_excite False
# 215 block5c_project_conv False
# 216 block5c_project_bn False
# 217 block5c_drop False
# 218 block5c_add False
# 219 block5d_expand_conv False
# 220 block5d_expand_bn False
# 221 block5d_expand_activation False
# 222 block5d_dwconv False
# 223 block5d_bn False
# 224 block5d_activation False
# 225 block5d_se_squeeze False
# 226 block5d_se_reshape False
# 227 block5d_se_reduce False
# 228 block5d_se_expand False
# 229 block5d_se_excite False
# 230 block5d_project_conv False
# 231 block5d_project_bn False
# 232 block5d_drop False
# 233 block5d_add False
# 234 block6a_expand_conv False
# 235 block6a_expand_bn False
# 236 block6a_expand_activation False
# 237 block6a_dwconv_pad False
# 238 block6a_dwconv False
# 239 block6a_bn False
# 240 block6a_activation False
# 241 block6a_se_squeeze False
# 242 block6a_se_reshape False
# 243 block6a_se_reduce False
# 244 block6a_se_expand False
# 245 block6a_se_excite False
# 246 block6a_project_conv False
# 247 block6a_project_bn False
# 248 block6b_expand_conv False
# 249 block6b_expand_bn False
# 250 block6b_expand_activation False
# 251 block6b_dwconv False
# 252 block6b_bn False
# 253 block6b_activation False
# 254 block6b_se_squeeze False
# 255 block6b_se_reshape False
# 256 block6b_se_reduce False
# 257 block6b_se_expand False
# 258 block6b_se_excite False
# 259 block6b_project_conv False
# 260 block6b_project_bn False
# 261 block6b_drop False
# 262 block6b_add False
# 263 block6c_expand_conv False
# 264 block6c_expand_bn False
# 265 block6c_expand_activation False
# 266 block6c_dwconv False
# 267 block6c_bn False
# 268 block6c_activation False
# 269 block6c_se_squeeze False
# 270 block6c_se_reshape False
# 271 block6c_se_reduce False
# 272 block6c_se_expand False
# 273 block6c_se_excite False
# 274 block6c_project_conv False
# 275 block6c_project_bn False
# 276 block6c_drop False
# 277 block6c_add False
# 278 block6d_expand_conv False
# 279 block6d_expand_bn False
# 280 block6d_expand_activation False
# 281 block6d_dwconv False
# 282 block6d_bn False
# 283 block6d_activation False
# 284 block6d_se_squeeze False
# 285 block6d_se_reshape False
# 286 block6d_se_reduce False
# 287 block6d_se_expand False
# 288 block6d_se_excite False
# 289 block6d_project_conv False
# 290 block6d_project_bn False
# 291 block6d_drop False
# 292 block6d_add False
# 293 block6e_expand_conv False
# 294 block6e_expand_bn False
# 295 block6e_expand_activation False
# 296 block6e_dwconv False
# 297 block6e_bn False
# 298 block6e_activation False
# 299 block6e_se_squeeze False
# 300 block6e_se_reshape False
# 301 block6e_se_reduce False
# 302 block6e_se_expand False
# 303 block6e_se_excite False
# 304 block6e_project_conv False
# 305 block6e_project_bn False
# 306 block6e_drop False
# 307 block6e_add False
# 308 block7a_expand_conv False
# 309 block7a_expand_bn False
# 310 block7a_expand_activation False
# 311 block7a_dwconv False
# 312 block7a_bn False
# 313 block7a_activation False
# 314 block7a_se_squeeze False
# 315 block7a_se_reshape False
# 316 block7a_se_reduce False
# 317 block7a_se_expand False
# 318 block7a_se_excite False
# 319 block7a_project_conv False
# 320 block7a_project_bn False
# 321 block7b_expand_conv False
# 322 block7b_expand_bn False
# 323 block7b_expand_activation False
# 324 block7b_dwconv False
# 325 block7b_bn False
# 326 block7b_activation False
# 327 block7b_se_squeeze False
# 328 block7b_se_reshape False
# 329 block7b_se_reduce True
# 330 block7b_se_expand True
# 331 block7b_se_excite True
# 332 block7b_project_conv True
# 333 block7b_project_bn True
# 334 block7b_drop True
# 335 block7b_add True
# 336 top_conv True
# 337 top_bn True
# 338 top_activation True

# %%
# Compile the model
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

fine_tune_epoch = initial_epoch + 10
# fitting model
history_10_layer = model.fit(train_data,
                    epochs= fine_tune_epoch,
                    steps_per_epoch=len(train_data),
                    validation_data = valid_data,
                    validation_steps =len(valid_data),
                    initial_epoch=history.epoch[-1],
                    callbacks=[create_tensorboard_callback("training_logs", "efficientb1 Paddy disease_all_data_fine_tuning"), # track the model training logs
                                                                   model_checkpoint, # save only the best model during training
                                                                   early_stopping, # stop model after X epochs of no improvements
                                                                   reduce_lr]) # reduce the learning rate after X epochs of no improvements
# Out:
# Saving TensorBoard log files to: training_logs/efficientb1 Paddy disease_all_data_fine_tuning/20220920-211041
# Epoch 15/25
# 261/261 [==============================] - 39s 113ms/step - loss: 0.5645 - accuracy: 0.8304 - val_loss: 0.4417 - val_accuracy: 0.8693 - lr: 0.0010
# Epoch 16/25
# 261/261 [==============================] - 28s 104ms/step - loss: 0.1902 - accuracy: 0.9378 - val_loss: 0.4057 - val_accuracy: 0.8751 - lr: 0.0010
# Epoch 17/25
# 261/261 [==============================] - 28s 105ms/step - loss: 0.1254 - accuracy: 0.9616 - val_loss: 0.3436 - val_accuracy: 0.9106 - lr: 0.0010
# Epoch 18/25
# 261/261 [==============================] - 28s 106ms/step - loss: 0.0922 - accuracy: 0.9724 - val_loss: 0.3384 - val_accuracy: 0.9145 - lr: 0.0010
# Epoch 19/25
# 261/261 [==============================] - 28s 105ms/step - loss: 0.0539 - accuracy: 0.9855 - val_loss: 0.3237 - val_accuracy: 0.9231 - lr: 0.0010
# Epoch 20/25
# 261/261 [==============================] - 28s 106ms/step - loss: 0.0739 - accuracy: 0.9763 - val_loss: 0.3905 - val_accuracy: 0.9135 - lr: 0.0010
# Epoch 21/25
# 261/261 [==============================] - 28s 105ms/step - loss: 0.0642 - accuracy: 0.9829 - val_loss: 0.3145 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 22/25
# 261/261 [==============================] - 29s 107ms/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.2982 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 23/25
# 261/261 [==============================] - 28s 105ms/step - loss: 0.0294 - accuracy: 0.9910 - val_loss: 0.3501 - val_accuracy: 0.9178 - lr: 0.0010
# Epoch 24/25
# 260/261 [============================>.] - ETA: 0s - loss: 0.0494 - accuracy: 0.9859
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 261/261 [==============================] - 29s 106ms/step - loss: 0.0494 - accuracy: 0.9859 - val_loss: 0.3856 - val_accuracy: 0.9097 - lr: 0.0010
# Epoch 25/25
# 261/261 [==============================] - 28s 105ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.2555 - val_accuracy: 0.9471 - lr: 2.0000e-04

# %% [markdown]
# # Checking the performance of the fine tuned model on validation data

# %%
# Evaluating fine-tuned model
result_last_10_layers=model.evaluate(valid_data)
result_last_10_layers
# Out:
# 66/66 [==============================] - 6s 80ms/step - loss: 0.2555 - accuracy: 0.9471
# [0.2555144727230072, 0.9471408128738403]

# %%
#plot loss curve 
plot_loss_curves(history_10_layer)

# %% [markdown]
# ## Making predictions on test data

# %%
# Loading test data into batches from directory in order to make predictions on it 
test_data=tf.keras.utils.image_dataset_from_directory(directory=test_dir,
                                                      label_mode=None,
                                                      image_size=IMG_SIZE,
                                                      seed=42,
                                                      shuffle=False)
# Out:
# Found 3469 files belonging to 1 classes.

# %%
# Making predictions on test_data
pred_prob=model.predict(test_data,batch_size=32,verbose=1)
pred_prob
# Out:
# 109/109 [==============================] - 12s 86ms/step
# array([[8.9196625e-08, 8.5586616e-10, 1.8244446e-15, ..., 9.9999917e-01,
#         4.0586487e-10, 4.0671906e-09],
#        [2.5197250e-10, 4.5271262e-10, 1.3699507e-10, ..., 2.8342720e-07,
#         9.9986136e-01, 1.3819325e-04],
#        [1.7847599e-06, 3.4062739e-07, 7.7224195e-06, ..., 2.1941320e-03,
#         2.2549555e-03, 2.9258175e-05],
#        ...,
#        [3.3245362e-12, 1.0815905e-11, 2.1757051e-13, ..., 2.3641746e-06,
#         9.9999654e-01, 1.5898602e-08],
#        [2.2583013e-08, 9.9940109e-01, 1.3200280e-07, ..., 7.9166413e-05,
#         1.4471541e-06, 3.4445268e-06],
#        [5.2507834e-25, 8.2954499e-23, 6.2429108e-17, ..., 3.8516282e-14,
#         4.8154538e-16, 1.1983034e-18]], dtype=float32)

# %%
# Getting the highest predicted probabilites
pred=pred_prob.argmax(axis=1)
pred,pred.shape
# Out:
# (array([7, 8, 3, ..., 8, 1, 5]), (3469,))

# %%
# Getting class_names for the predicted class
pred_class=[class_names[x] for x in pred]

# Viewing first 10 predictions
pred_class[:10]
# Out:
# ['hispa',
#  'normal',
#  'blast',
#  'blast',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'brown_spot',
#  'hispa',
#  'normal']

# %% [markdown]
# # Making submission on kaggle

# %%
# Loading the sample_submission.csv into DataFrame and adding prediction columns to the loaded DataFrame 
import pandas as pd
predictions=pd.read_csv("sample_submission.csv")
predictions["label"]=pred_class
predictions.head()
# Out:
#      image_id   label
# 0  200001.jpg   hispa
# 1  200002.jpg  normal
# 2  200003.jpg   blast
# 3  200004.jpg   blast
# 4  200005.jpg   blast

# %%
# Exporting pandas Dataframe into csv file
predictions.to_csv('efficientb1_submission.csv',header=True,index = False)
files.download("efficientb1_submission.csv") # Download csv file

# %%
# Submitting csv file to kaggle
! kaggle competitions submit -c paddy-disease-classification -f efficientb1_submission.csv -m "Paddy Disease Classification"
# Out:
# 100% 70.4k/70.4k [00:02<00:00, 25.6kB/s]
# Successfully submitted to Paddy Doctor: Paddy Disease Classification
